# %%
import pandas as pd 
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
f=open("../../fuentes/Discurso 1.txt","r")  ### Discurso 1
s=open("../../fuentes/Discurso 2.txt","r")### Discurso 2

data = f.read()
data1 = s.read()

# %%
first_line = data.split('\n')[0]
second_line = data.split('\n')[1]

first_line1 = data1.split('\n')[0]
second_line1 = data1.split('\n')[1]

# %%
datos={  "Nombre del Discurso": [first_line,first_line1 ]
        ,"Autor":               [second_line,second_line1]
        ,"Cuerpo":              [data,data1]   
            }

Tablero=pd.DataFrame(datos) 
Tablero.head()
# Out:
#                                  Nombre del Discurso           Autor  \
# 0  "Este fue el discurso de Juan Guaidó al asumir...     Juan Guaidó
# 1  Discurso de juramentación de Nicolás Maduro co...  Nicolas Maduro
#
#                                               Cuerpo
# 0  "Este fue el discurso de Juan Guaidó al asumir...
# 1  Discurso de juramentación de Nicolás Maduro co...

# %%
stop_words_sp = set(stopwords.words('spanish'))

# %%
def generateWordCloud(data,title):
    wordcloud = WordCloud(background_color='white',
        stopwords=stop_words_sp,
        max_words=20,
        max_font_size=200, 
        scale=3,
        random_state=3).generate(str(data))
    wordcloud.recolor(random_state=1)
    plt.figure(figsize=(20, 15))
    plt.title(title, fontsize=20,color='blue')
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
for cols in Tablero.index:
  generateWordCloud(Tablero.loc[cols,'Cuerpo'],Tablero.loc[cols,'Nombre del Discurso'])

# %%
# Out:
#   File "<ipython-input-23-4536770e8ed0>", line 2
#     generateWordCloud(Tablero.loc[cols,'Cuerpo'],Tablero.loc[cols,'Nombre
#                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
archivo = pd.read_csv('../../fuentes/lecturaCSV.csv', sep=',')
archivo.head()
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0   1/02/2009 6:17  Product1  1200   Mastercard           carolina
# 1   1/02/2009 4:53  Product1  1200         Visa             Betina
# 2  1/02/2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3  1/03/2009 14:44  Product1  1200         Visa              Gouya
# 4  1/04/2009 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country  Account_Created  \
# 0                      Basildon   England  United Kingdom   1/02/2009 6:00
# 1  Parkville                           MO   United States   1/02/2009 4:42
# 2  Astoria                             OR   United States  1/01/2009 16:21
# 3                        Echuca  Victoria       Australia    9/25/05 21:13
# 4  Cahaba Heights                      AL   United States   11/15/08 15:47
#
#         Last_Login   Latitude   Longitude
# 0   1/02/2009 6:08  51.500000   -1.116667
# ...

# %%
archivo['Name']
# Out:
# 0               carolina
# 1                 Betina
# 2      Federica e Andrea
# 3                  Gouya
# 4                Gerd W
# 5               LAURENCE
# 6                  Fleur
# 7                   adam
# 8        Renee Elisabeth
# 9                  Aidan
# 10                 Stacy
# 11                 Heidi
# 12                 Sean
# 13               Georgia
# 14               Richard
# 15                Leanne
# 16                 Janet
# 17               barbara
# 18                Sabine
# 19                  Hani
# 20                Jeremy
# 21                 Janis
# 22                Nicola
# 23                asuman
# 24                  Lena
# 25                  Lisa
# 26         Bryan Kerrene
# 27                 chris
# 28                Maxine
# 29                Family
#              ...
# 968                clara
# 969                Selma
# 970        Doug and Tina
# 971               Lauren
# 972                  Jen
# 973               gladys
# ...

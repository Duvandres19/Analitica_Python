# %%
import nltk
from nltk.corpus import stopwords
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
text = """Buenos días Señora Lucelly Bienvenida a Chec. Mi nombre es Tatiana Holguín y seré su asesora durante esta consulta. 
Señora Lucelly le confirmo que la factura nos registra a su nombre LUCELLY MORALES OSORIO en la dirección CRA 3 4 03, 
¿es correcto?. Permítame un momento por favor, vamos a consultar la información. Señora Lucelly, 
por favor permanezca un momento más en línea ya le voy a dar toda la información, me disculpa la tardanza. 
Muy formal por su espera en línea señora Lucelly disculpe la demora, en cuanto a su consulta si puede pagar un recibo desde 
cualquier otro lugar que no sea La Dorada, si lo puede hacer siempre y cuando esta se encuentre vigente y que no esté vencida. 
Lo puede hacer ya sea en Bancolombia, Banco de Bogotá, Davivienda o también por medio de Éxito, Pomona, Carulla y Surtimax. 
Claro está que para mayor seguridad usted en el reverso de la factura encontrará mas medios de pago. 
Adicionalmente le confirmo señora Lucelly que su factura ya está vencida desde el día 29/12/2017
y está por un valor de $ 36,180. Permítame un momento mas valido si por medio de nuestra página puede hacerlo
y si tiene el pago habilitado. Gracias señora Lucelly por su espera en este momento acabo de validar en sistema
y si puede pagar por nuestra página web www.chec.com.co. Para ello debe de hacerlo con esta referencia de pago 540381123171111. 
Si desea puede intentar yo la esperaría. Si señora Lucelly sólo cancelaría con la referencia. Claro que si. Señora Lucelly, 
si pudo cancelar?. Me parece perfecto, ¿le puedo ayudar en algo más?. Señora Lucelly estos pagos no los podemos visualizar 
inmediatamente ya que este puede tardar al rededor de 24 horas. Usted nos puede estar contactando para validar si el pago nos 
registra. O también puede enviar el soporte al correo de recaudoempresarial@chec.com.co para que se pueda actualizar el pago.  
Ya que como su factura venció el 29/12/2017 puede correr riesgo de suspensión si no se evidencia el pago rapidamente.   
Entonces lo ideal es que como le informo adjunte el soporte a ese correo al igual que todos los dato personales y por 
supuesto el número de cuenta de la factura, ¿le parece?. De acuerdo señora Lucelly, ¿le puedo ayudar en algo más?. 
¿Continúa en línea señora Lucelly?. A usted señora Lucelly por haberse comunicado con Chec, 
esperamos contar con su visita en una próxima oportunidad, que tenga un excelente día."""

text_1 =""""Sr, Fernando le explico: Para realizar la cancelación de la financiación que actualmente tiene con la CHEC, 
    debe hacerlo directamente con el área de financiaciones.  Puede comunicarse a la línea de financiación desde su celular marcando 
    #415 o el 115 o al 01 8000 912 432, también desde el conmutador marcando al (6) 889 90 00 ext. #0.  
    Pérmitame señor Fernando, antes que me finalice reviso el estado de su factura.  
    Gracias por su tiempo en línea, con los datos que me brinda me registra una factura a nombre de FERNANDO OSORIO SALAZAR en la 
    dirección CLL 82 37A 53 LUSITANIA - LUSITANIA para el municipio de Manizales ¿es correcto?  
    Me registra un valor congelado por $99.786 que se congelo automáticamente para financiar, ¿este es el valor que desea cancelar?
    Este saldo, si es posible descongelarlo por este medio, debido a que es una financiación automática.   
    Le puedo descongelar este saldo y enviarle un cupón con el valor total.  
    Este cupón tiene un dia de vencimiento, es decir que se tedría que cancelar el día de hoy.  
    Permítame por favor un momento, realizo el proceso. Le agradezco el tiempo que me ha dedicado, 
    le informo que en este momento acabo de realizar el descongelamiento de su saldo, 
    quedando un valor total de la factura por $182,886.  Señor Fernando aproximadamente en una hora,  
    este valor se va ver reflejado en los puntos de Susuerte y Apostar, así que con el número de cuenta se puede acercar a cancelar.
    Igualmente si desea, le puedo enviar el cupón a su correo.  Muy buenos dias señor Fernando bienvenido a Chec.
    Mi nombre es Deysi Gil y seré su asesora durante esta consulta. Me confirma por favor el correo. 
    De acuerdo señor Fernando en contados minutos se estará enviando la copia del cupón.  
    Es con mucho gusto ¿le puedo ayudar en algo más? Gracias por comunicarse con Chec, 
    esperamos contar con su visita en una próxima oportunidad; le deseo que tenga un buen día igualmente! 
    http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx Llamada desconectada. [Fernando Osorio Salazar] 
    Señor Fernando ¿Cómo amanece el día de hoy?  Me alegro, muy bien gracias. 
    Me informa que desea cancelar una financiación de su factura ¿es correcto? """
text_2 = """Llamada desconectada. [Fernando Osorio Salazar] ¡Buen día! Señora Yelitza ¡Bienvenida a Chec! 
Mi nombre es Alejandro Salinas y espero que se encuentre muy bien, es un gusto para mi ser su asesor durante esta consulta.  
¿Se encuentra en línea? El saldo actual de su cuenta es $520,640 pesos.  
Señor Usuario, no hemos recibido respuesta durante los últimos 2 minutos, 
puede contactarnos nuevamente para continuar con la asesoría, 
Recuerde nuestras líneas de atención al cliente para reportes de daño la línea 115; 
Peticiones, Quejas o Reclamos a través de la línea #415 o 018000912432 en el horario de Domingo a Domingo de 06:am a 10:00pm o 
nuestro canal virtual Chat que labora de Lunes a Viernes de 6:00am a 10:00pm y Sábados de 7:00am a 4:00pm. 
http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx"""
text_3 = """¡Fue para mi todo un gusto atenderle!   ¡Gracias por comunicarse con Chec! 
Esperamos contar con su visita en una próxima oportunidad; Le deseo tenga feliz día. 
¡Buen día! Señor José ¡Bienvenido a Chec! Mi nombre es Alejandro Salinas y espero que se encuentre muy bien, 
es un gusto para mi ser su asesor durante esta consulta.  ¿Podría hacerme un poco de claridad sobre el requerimiento? 
¿Desea financiar? El proceso se realiza por medio de nuestra línea de atención 115, #415 o 01 8000 912 432, 
en el momento nuestras líneas pueden estar un poco congestionadas por lo que le ofrecemos nuestras más sinceras disculpas, 
lo invitamos a tener paciencia a la hora de comunicarse y con todo gusto daremos atención a su requerimiento. 
¿Puedo ayudarle en algo más? ¡Fue para mi todo un gusto atenderle!   
¡Gracias por comunicarse con Chec! Esperamos contar con su visita en una próxima oportunidad; 
Le deseo tenga feliz día. 
http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx"""
text_4 = """http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx Muy buenos dias señora Lina bienvenida a Chec. 
Mi nombre es Deysi Gil y seré su asesora durante esta consulta. ¿Cómo se encuentra el día de hoy, en que le puedo colaborar?  
Permítame un momento por favor, vamos a consultar la información. Gracias por su tiempo en línea, 
con los datos que me brinda me registra una factura a nombre de LINA MARIA SANCHEZ CANO en la 
dirección CLL 17 1A 13 M 4 C 23 - CAMPESTRE B para el municipio de Dosquebradas ¿es correcto?  
Me registra una factura para el mes de Junio por $ 56,182 la cual se aplicó un saldo a favor que presentaba por $72,210. 
Actualmente continúa con un saldo a favor por $9,890 que se descontará en la próxima factura.  
Es correcto! para este mes su factura quedo saldada con el saldo a favor.  Es para especificar el saldo a favor.  
no señora, la CHEC no cobra recargo, igualmente su factura tenía un saldo a favor.  
Es con mucho! ¿le puedo ayudar en algo más? Gracias por comunicarse con Chec, 
esperamos contar con su visita en una próxima oportunidad; le deseo que tenga un buen día! 
http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx Llamada desconectada. [Lina Sanchez]"""

tokens = [t for t in text_1.split()]

freq = nltk.FreqDist(tokens)
nGrama = (list(nltk.bigrams(tokens)))

for key,val in freq.items():

    print (str(key) + ':' + str(val))
print(nGrama)
# Out:
# "Sr,:1
# Fernando:5
# le:4
# explico::1
# Para:1
# realizar:2
# la:7
# cancelación:1
# de:15
# financiación:4
# que:13
# actualmente:1
# tiene:2
# con:8
# CHEC,:1
# debe:1
# hacerlo:1
# directamente:1
# el:15
# área:1
# financiaciones.:1
# Puede:1
# comunicarse:2
# a:6
# línea:1
# desde:2
# su:8
# celular:1
# marcando:2
# #415:1
# o:2
# 115:1
# al:2
# 01:1
# 8000:1
# 912:1
# 432,:1
# también:1
# conmutador:1
# (6):1
# 889:1
# 90:1
# 00:1
# ext.:1
# #0.:1
# Pérmitame:1
# señor:3
# Fernando,:1
# antes:1
# me:4
# finalice:1
# reviso:1
# estado:1
# factura.:1
# Gracias:2
# por:7
# tiempo:2
# en:8
# línea,:1
# los:2
# datos:1
# brinda:1
# registra:2
# una:5
# factura:3
# nombre:2
# FERNANDO:1
# OSORIO:1
# SALAZAR:1
# dirección:1
# CLL:1
# 82:1
# 37A:1
# 53:1
# LUSITANIA:2
# -:1
# para:2
# municipio:1
# Manizales:1
# ¿es:2
# correcto?:2
# Me:4
# un:6
# valor:5
# congelado:1
# $99.786:1
# se:5
# congelo:1
# automáticamente:1
# financiar,:1
# ¿este:1
# es:5
# desea:2
# cancelar?:1
# Este:2
# ...

# %%
clean_tokens = tokens[:]
sr = stopwords.words('spanish')
for token in tokens:

    if token in sr:

        clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

for key,val in freq.items():

    print (str(key) + ':' + str(val))
# Out:
# "Sr,:1
# Fernando:5
# explico::1
# Para:1
# realizar:2
# cancelación:1
# financiación:4
# actualmente:1
# CHEC,:1
# debe:1
# hacerlo:1
# directamente:1
# área:1
# financiaciones.:1
# Puede:1
# comunicarse:2
# línea:1
# celular:1
# marcando:2
# #415:1
# 115:1
# 01:1
# 8000:1
# 912:1
# 432,:1
# conmutador:1
# (6):1
# 889:1
# 90:1
# 00:1
# ext.:1
# #0.:1
# Pérmitame:1
# señor:3
# Fernando,:1
# finalice:1
# reviso:1
# factura.:1
# Gracias:2
# tiempo:2
# línea,:1
# datos:1
# brinda:1
# registra:2
# factura:3
# nombre:2
# FERNANDO:1
# OSORIO:1
# SALAZAR:1
# dirección:1
# CLL:1
# 82:1
# 37A:1
# 53:1
# LUSITANIA:2
# -:1
# municipio:1
# Manizales:1
# ¿es:2
# correcto?:2
# Me:4
# valor:5
# congelado:1
# $99.786:1
# congelo:1
# automáticamente:1
# financiar,:1
# ¿este:1
# desea:2
# cancelar?:1
# Este:2
# saldo,:2
# si:2
# posible:1
# descongelarlo:1
# medio,:1
# debido:1
# automática.:1
# Le:2
# puedo:3
# descongelar:1
# saldo:1
# enviarle:1
# cupón:3
# total.:1
# dia:1
# vencimiento,:1
# ...

# %%
from nltk.tokenize import sent_tokenize
text_ = "señora Lucelly le confirmo que la factura nos registra a su nombre LUCELLY MORALES OSORIO en la dirección CRA 3 4 03, ¿es correcto?"
text_3 = "señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice. ud no habla claro debria de llamar mas tarde"
words = ["llame mas tarde", " aqui no es", "hable mas fuerte", "no le entiendo","no habla claro", "llamar mas tarde"]
frases = sent_tokenize(text_3,"spanish")

for word in words:
    if word in frases[0]:
        print(1)
        print(word)
    print(frases)
# Out:
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']
# 1
#  aqui no es
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']
# 1
# no le entiendo
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']
# ['señora andrea debe de ir a nuestras oficinas, aqui no es y no le entiendo lo que dice.', 'ud no habla claro debria de llamar mas tarde']

# %%
from nltk.tokenize import word_tokenize

word = 'hola'

print(word_tokenize(word))
# Out:
# ['hola']

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import SpaceTokenizer
sentence = "i spoke with sumit and rajesh and Samit about the gridlock situation last night @ around 8 pm last nite"
tokenizer = SpaceTokenizer()
toks = tokenizer.tokenize(sentence)
pos = pos_tag(toks)
chunked_nes = ne_chunk(pos) 

nes = [' '.join(map(lambda x: x[0], ne.leaves())) for ne in chunked_nes if isinstance(ne, nltk.tree.Tree)]
print(nes)
# Out:
# ['Samit']

# %%
tokens = nltk.tokenize.word_tokenize(sentence)
pos = nltk.pos_tag(tokens)
sentt = nltk.ne_chunk(pos, binary = False)
print(sentt)
person = []
for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
    for leave in subtree.leaves():
        person.append(leave)
print("person=", person)
# Out:
# (S
#   i/JJ
#   spoke/VBD
#   with/IN
#   sumit/NN
#   and/CC
#   rajesh/NN
#   and/CC
#   (PERSON Samit/NNP)
#   about/IN
#   the/DT
#   gridlock/NN
#   situation/NN
#   last/JJ
#   night/NN
#   @/NN
#   around/IN
#   8/CD
#   pm/NN
#   last/JJ
#   nite/JJ)
# person= [('Samit', 'NNP')]

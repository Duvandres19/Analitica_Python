# %%
import stanza
# stanza.download('es')

# %%
nlp = stanza.Pipeline(lang='es')
# cadena_cats = "Buenos días Señora Lucelly Bienvenida a Chec. Mi nombre es Tatiana Holguín y seré su asesora durante esta consulta. Señora Lucelly le confirmo que la factura nos registra a su nombre LUCELLY MORALES OSORIO en la dirección CRA 3 4 03, ¿es correcto?. Permítame un momento por favor, vamos a consultar la información. Señora Lucelly, por favor permanezca un momento más en línea ya le voy a dar toda la información, me disculpa la tardanza. Muy formal por su espera en línea señora Lucelly disculpe la demora, en cuanto a su consulta si puede pagar un recibo desde cualquier otro lugar que no sea La Dorada, si lo puede hacer siempre y cuando esta se encuentre vigente y que no esté vencida. Lo puede hacer ya sea en Bancolombia, Banco de Bogotá, Davivienda o también por medio de Éxito, Pomona, Carulla y Surtimax. Claro está que para mayor seguridad usted en el reverso de la factura encontrará mas medios de pago. Adicionalmente le confirmo señora Lucelly que su factura ya está vencida desde el día 29/12/2017 y está por un valor de $ 36,180. Permítame un momento mas valido si por medio de nuestra página puede hacerlo y si tiene el pago habilitado. Gracias señora Lucelly por su espera en este momento acabo de validar en sistema y si puede pagar por nuestra página web www.chec.com.co. Para ello debe de hacerlo con esta referencia de pago 540381123171111. Si desea puede intentar yo la esperaría. Si señora Lucelly sólo cancelaría con la referencia. Claro que si. Señora Lucelly, si pudo cancelar?. Me parece perfecto, ¿le puedo ayudar en algo más?. Señora Lucelly estos pagos no los podemos visualizar inmediatamente ya que este puede tardar al rededor de 24 horas. Usted nos puede estar contactando para validar si el pago nos registra. O también puede enviar el soporte al correo de recaudoempresarial@chec.com.co para que se pueda actualizar el pago.  Ya que como su factura venció el 29/12/2017 puede correr riesgo de suspensión si no se evidencia el pago rapidamente.   Entonces lo ideal es que como le informo adjunte el soporte a ese correo al igual que todos los dato personales y por supuesto el número de cuenta de la factura, ¿le parece?. De acuerdo señora Lucelly, ¿le puedo ayudar en algo más?. ¿Continúa en línea señora Lucelly?. A usted señora Lucelly por haberse comunicado con Chec, esperamos contar con su visita en una próxima oportunidad, que tenga un excelente día."
cadena_cats ="Buenas tardes, Señora  Bienvenida a Chec. Mi nombre es Cristina Rodas   y seré su asesora durante esta consulta. Señora Liliana y que error tiene? Señora Liliana ¿Continúa en línea? http://servicio.asistenciachat.com/website/chec_chat/encuestam.aspx Llamada desconectada. [Liliana Crdenas]"
doc = nlp(cadena_cats)
doc.sentences[1].print_dependencies()
# Out:
# 2020-09-06 09:55:40 INFO: Loading these models for language: es (Spanish):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# ...
#
# 2020-09-06 09:55:40 INFO: Use device: cpu
# 2020-09-06 09:55:40 INFO: Loading: tokenize
# 2020-09-06 09:55:40 INFO: Loading: mwt
# 2020-09-06 09:55:40 INFO: Loading: pos
# 2020-09-06 09:55:41 INFO: Loading: lemma
# 2020-09-06 09:55:41 INFO: Loading: depparse
# 2020-09-06 09:55:43 INFO: Loading: ner
# 2020-09-06 09:55:45 INFO: Done loading processors!
# ('Mi', 2, 'det')
# ('nombre', 4, 'nsubj')
# ('es', 4, 'cop')
# ('Cristina', 0, 'root')
# ('Rodas', 4, 'flat')
# ('y', 9, 'cc')
# ('seré', 9, 'cop')
# ('su', 9, 'det')
# ('asesora', 4, 'conj')
# ('durante', 12, 'case')
# ('esta', 12, 'det')
# ('consulta', 9, 'obl')
# ('.', 4, 'punct')

# %%
review = """Sin embargo, no las tiene todas consigo Zombie y es, precisamente, cuando tiene que lograr mantener la tensión tras el impetuoso retorno cuando patina. El director pierde el pulso vibrante para dejarse llevar por una trama más apagada, sin chispa y del todo previsible. El segundo tercio del film se desploma. Ese montaje paralelo donde vemos, de un lado a Strode intentando reponerse y a Myers resucitando de sus cenizas y deambulando cual sombra por el campo en un dilatado regreso a Haddonfield, se desinfla. Previsible, aburrido, sin pulso. Y dejando entrever las costuras de un guión en el que su creador no logra sostener el ritmo.
Las pesadillas de Strode y los asesinatos de Myers se vuelven aburridos. Y no solo por repetición insulsa sino también porque Zombie se desata con escenas más creativas, pero carentes de originalidad. Donde ese doble juego entre realidad y ensoñación se vuelve insistente, pierde sutileza para convertirse en una evidente falta de recursos e imaginación. Aquí debería haber dejado su impronta y solo consigue rozar lo convencional, incluso lo ridículo.
Basta comprobar las apariciones del Dr. Loomis (Malcolm McDowell) que rozan lo cómico o la insistencia con la que nos quiere recordar ese sueño de Myers con angelical madre y el caballo blanco, que acaban tomando un protagonismo excesivo y perdiendo toda la sugerencia que debería acompañar para convertirse en una incómoda y repetida presencia que acaba entorpeciendo el avance de la historia en varias escenas.
Lamentablemente el desagisado hace llegar al tramo final sin muchas esperanzas de sorpresa. Y menos aún de tensión. El largo regreso de Myers y el desenlace ya no recuperan la brillantez inicial. Y muy al contrario demuestra que quizás Zombie dispuso de una gran oportunidad para reivindicarse pero que no supo aprovechar."""
review_ = """Buenos días Señora Lucelly Bienvenida a Chec. Mi nombre es Tatiana Holguín y seré su asesora durante esta consulta. 
Señora Lucelly le confirmo que la factura nos registra a su nombre LUCELLY MORALES OSORIO en la dirección CRA 3 4 03, 
¿es correcto?. Permítame un momento por favor, vamos a consultar la información. Señora Lucelly, 
por favor permanezca un momento más en línea ya le voy a dar toda la información, me disculpa la tardanza. 
Muy formal por su espera en línea señora Lucelly disculpe la demora, en cuanto a su consulta si puede pagar un recibo desde 
cualquier otro lugar que no sea La Dorada, si lo puede hacer siempre y cuando esta se encuentre vigente y que no esté vencida. 
Lo puede hacer ya sea en Bancolombia, Banco de Bogotá, Davivienda o también por medio de Éxito, Pomona, Carulla y Surtimax. 
Claro está que para mayor seguridad usted en el reverso de la factura encontrará mas medios de pago. 
Adicionalmente le confirmo señora Lucelly que su factura ya está vencida desde el día 29/12/2017
y está por un valor de $ 36,180. Permítame un momento mas valido si por medio de nuestra página puede hacerlo
y si tiene el pago habilitado. Gracias señora Lucelly por su espera en este momento acabo de validar en sistema
y si puede pagar por nuestra página web www.chec.com.co. Para ello debe de hacerlo con esta referencia de pago 540381123171111. 
Si desea puede intentar yo la esperaría. Si señora Lucelly sólo cancelaría con la referencia. Claro que si. Señora Lucelly, 
si pudo cancelar?. Me parece perfecto, ¿le puedo ayudar en algo más?. Señora Lucelly estos pagos no los podemos visualizar 
inmediatamente ya que este puede tardar al rededor de 24 horas. Usted nos puede estar contactando para validar si el pago nos 
registra. O también puede enviar el soporte al correo de recaudoempresarial@chec.com.co para que se pueda actualizar el pago.  
Ya que como su factura venció el 29/12/2017 puede correr riesgo de suspensión si no se evidencia el pago rapidamente.   
Entonces lo ideal es que como le informo adjunte el soporte a ese correo al igual que todos los dato personales y por 
supuesto el número de cuenta de la factura, ¿le parece?. De acuerdo señora Lucelly, ¿le puedo ayudar en algo más?. 
¿Continúa en línea señora Lucelly?. A usted señora Lucelly por haberse comunicado con Chec, 
esperamos contar con su visita en una próxima oportunidad, que tenga un excelente día."""

# %%
doc_review = nlp(review_)

for sent in doc_review.sentences:
    for dep in sent.dependencies:
        if dep[1] == 'amod':
            print(dep[2].text, dep[0].text)
# Out:
# formal disculpe
# mayor seguridad
# valido momento
# habilitado pago
# web página
# personales dato
# próxima oportunidad
# excelente día

# %%
for sent in doc_review.sentences:
    for word in sent.words:
        # print(word)
        if word.upos != 'PUNCT':
            print(word.text)
# Out:
# Buenos
# días
# Señora
# Lucelly
# Bienvenida
# a
# Chec
# Mi
# nombre
# es
# Tatiana
# Holguín
# y
# seré
# su
# asesora
# durante
# esta
# consulta
# Señora
# Lucelly
# le
# confirmo
# que
# la
# factura
# nos
# registra
# a
# su
# nombre
# LUCELLY
# MORALES
# OSORIO
# en
# la
# dirección
# CRA
# 3
# 4
# 03
# es
# correcto
# Permítame
# un
# momento
# por
# favor
# vamos
# a
# consultar
# la
# información
# Señora
# Lucelly
# por
# favor
# permanezca
# un
# momento
# más
# en
# línea
# ya
# le
# voy
# a
# dar
# toda
# la
# información
# me
# disculpa
# la
# tardanza
# Muy
# formal
# por
# su
# espera
# en
# línea
# señora
# Lucelly
# disculpe
# la
# demora
# en
# cuanto
# a
# su
# consulta
# si
# puede
# pagar
# un
# recibo
# desde
# cualquier
# otro
# lugar
# que
# no
# sea
# La
# Dorada
# si
# lo
# puede
# hacer
# siempre
# y
# cuando
# esta
# se
# encuentre
# vigente
# y
# que
# no
# esté
# vencida
# Lo
# puede
# hacer
# ya
# sea
# en
# Bancolombia
# Banco
# de
# Bogotá
# ...
